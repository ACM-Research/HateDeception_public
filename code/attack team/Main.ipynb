# %% [markdown]
# # Welcome to Deepnote

# %% [markdown]
# ## Todo:

# %% [markdown]
# - [ ]

# %% [markdown]
# - [ ]

# %% [markdown]
# - [ ]

# %%
# !pip install textattack[tensorflow]
# Out:
# Collecting textattack[tensorflow]
#   Downloading textattack-0.3.8-py3-none-any.whl (418 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.7/418.7 KB 32.9 MB/s eta 0:00:00
# Collecting pycld2
#   Downloading pycld2-0.41.tar.gz (41.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 33.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers>=4.21.0
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 93.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (1.2.5)
# Requirement already satisfied: numpy>=1.21.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (1.23.4)
# Collecting pinyin==0.4.0
#   Downloading pinyin-0.4.0.tar.gz (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 92.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jieba
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 60.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=1.4.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (1.9.3)
# Collecting language-tool-python
#   Downloading language_tool_python-2.7.1-py3-none-any.whl (34 kB)
# Collecting click<8.1.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 KB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (4.64.1)
# Collecting datasets==2.4.0
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 KB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (3.7)
# Collecting OpenHowNet
#   Downloading OpenHowNet-2.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (1.12.1)
# Collecting lru-dict
#   Downloading lru_dict-1.1.8-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Collecting lemminflect
#   Downloading lemminflect-0.2.3-py3-none-any.whl (769 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.7/769.7 KB 13.3 MB/s eta 0:00:00
# Collecting editdistance
#   Downloading editdistance-0.6.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.4/282.4 KB 31.5 MB/s eta 0:00:00
# Collecting word2number
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting num2words
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 KB 23.8 MB/s eta 0:00:00
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting more-itertools
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 KB 13.3 MB/s eta 0:00:00
# Collecting flair
#   Downloading flair-0.12.2-py3-none-any.whl (373 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 KB 55.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (3.8.0)
# Collecting bert-score>=0.3.5
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 KB 13.6 MB/s eta 0:00:00
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Collecting tensorflow-hub
#   Downloading tensorflow_hub-0.13.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 KB 15.5 MB/s eta 0:00:00
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 25.9 MB/s eta 0:00:00
# Collecting tensorflow==2.9.1
#   Downloading tensorflow-2.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 2.5 MB/s eta 0:00:00
# Collecting tensorflow-estimator==2.9.0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 KB 56.1 MB/s eta 0:00:00
# Collecting tensorflow-text>=2
#   Downloading tensorflow_text-2.12.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 104.0 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (9.0.0)
# Requirement already satisfied: aiohttp in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (3.8.3)
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (21.3)
# Requirement already satisfied: dill<0.3.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (0.3.5.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: requests>=2.19.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (2.28.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 33.2 MB/s eta 0:00:00
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2023.4.0-py3-none-any.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.0/154.0 KB 31.7 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 28.0 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 51.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (3.19.6)
# Requirement already satisfied: libclang>=13.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (14.0.6)
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (2.0.1)
# Requirement already satisfied: absl-py>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.50.0)
# Requirement already satisfied: six>=1.12.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (4.4.0)
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 109.3 MB/s eta 0:00:00
# Requirement already satisfied: astunparse>=1.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.6.3)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 109.8 MB/s eta 0:00:00
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (0.27.0)
# Requirement already satisfied: wrapt>=1.11.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.14.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (3.3.0)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (58.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (3.7.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from bert-score>=0.3.5->textattack[tensorflow]) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=1.0.1->textattack[tensorflow]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.0.1->textattack[tensorflow]) (2022.5)
# Collecting tensorflow-text>=2
#   Downloading tensorflow_text-2.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 107.2 MB/s eta 0:00:00
#   Downloading tensorflow_text-2.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 95.8 MB/s eta 0:00:00
#   Downloading tensorflow_text-2.9.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 127.0 MB/s eta 0:00:00
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 KB 74.9 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from transformers>=4.21.0->textattack[tensorflow]) (2022.9.13)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.5 MB/s eta 0:00:00
# Collecting pptree
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting segtok>=1.5.7
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting pytorch-revgrad
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 KB 80.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (0.9.0)
# Requirement already satisfied: boto3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (1.24.95)
# Collecting transformer-smaller-training-vocab>=0.2.1
#   Downloading transformer_smaller_training_vocab-0.2.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: scikit-learn>=0.21.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (1.1.2)
# Collecting sqlitedict>=1.6.0
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting hyperopt>=0.2.7
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 89.2 MB/s eta 0:00:00
# Collecting deprecated>=1.2.4
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting mpld3==0.3
#   Downloading mpld3-0.3.tar.gz (788 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 KB 95.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (4.9.1)
# Collecting gdown==4.4.0
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 13.0 MB/s eta 0:00:00
# Collecting conllu>=4.0
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Collecting gensim>=3.8.0
#   Downloading gensim-4.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 64.4 MB/s eta 0:00:00
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Collecting janome
#   Downloading Janome-0.4.2-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 86.3 MB/s eta 0:00:00
# Collecting bpemb>=0.3.2
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from gdown==4.4.0->flair->textattack[tensorflow]) (4.11.1)
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk->textattack[tensorflow]) (1.2.0)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting anytree
#   Downloading anytree-2.8.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow==2.9.1->textattack[tensorflow]) (0.38.4)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 93.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (1.2.0)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim>=3.8.0->flair->textattack[tensorflow]) (5.2.1)
# Requirement already satisfied: future in /shared-libs/python3.9/py/lib/python3.9/site-packages (from hyperopt>=0.2.7->flair->textattack[tensorflow]) (0.18.2)
# Collecting networkx>=2.2
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 95.3 MB/s eta 0:00:00
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 KB 51.9 MB/s eta 0:00:00
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (9.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.4.0->textattack[tensorflow]) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.4.0->textattack[tensorflow]) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.4.0->textattack[tensorflow]) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.21.3->flair->textattack[tensorflow]) (3.1.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (2.13.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (2.2.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from boto3->flair->textattack[tensorflow]) (1.0.1)
# Requirement already satisfied: botocore<1.28.0,>=1.27.95 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from boto3->flair->textattack[tensorflow]) (1.27.95)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from boto3->flair->textattack[tensorflow]) (0.6.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ftfy->flair->textattack[tensorflow]) (0.2.5)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 KB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (5.0.0)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4->gdown==4.4.0->flair->textattack[tensorflow]) (2.3.2.post1)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (3.9.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (3.2.2)
# Building wheels for collected packages: pinyin, gdown, mpld3, jieba, pycld2, word2number, docopt, sqlitedict, langdetect, pptree
#   Building wheel for pinyin (setup.py) ... done
#   Created wheel for pinyin: filename=pinyin-0.4.0-py3-none-any.whl size=3630495 sha256=41b11dc435d742b05395626d7bf15bd44f56370409d06cc2594c4fdae013c10e
#   Stored in directory: /root/.cache/pip/wheels/91/4d/03/beb69f9530864b62f295333257151b845f5f871b9a32665b9e
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14775 sha256=ddd55dfa850e91b6430cad696044282511b2e6e189f2c4e0d41049bf957d764a
#   Stored in directory: /root/.cache/pip/wheels/7d/37/b6/b2a79c75e898c0b8e46ff255102602d7159a10d9af0d80641a
#   Building wheel for mpld3 (setup.py) ... done
#   Created wheel for mpld3: filename=mpld3-0.3-py3-none-any.whl size=116702 sha256=fc06d9e240f1dc850fdab40967e7ad2f4304826a016f5c9a0f36cd674e19163d
#   Stored in directory: /root/.cache/pip/wheels/a6/f4/e6/e40ff9021f6b3854af70fa8ea004f5ab95672817462df08fed
#   Building wheel for jieba (setup.py) ... done
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314477 sha256=e837d172793bd1cbb67c4b46d8d73a87048262245d6a27eb3422dd3eb2dc9f93
#   Stored in directory: /root/.cache/pip/wheels/7d/74/cf/08c94db4b784e2c1ef675a600b7b5b281fd25240dcb954ee7e
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.41-cp39-cp39-linux_x86_64.whl size=9903392 sha256=7ad4a90bdd206fef931be72e66b22a1a8008efd4f887a739ed65585c197e149a
#   Stored in directory: /root/.cache/pip/wheels/ed/98/60/230df7a9368a02bf62e0e2719a31615b2aa82238dea526b637
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5582 sha256=ad98e716306ec2bca2e3d3081eb9a14b47e6f4701a2cd6e621465407e2ee8f5d
#   Stored in directory: /root/.cache/pip/wheels/a0/4a/5b/d2f2df5c344ddbecb8bea759872c207ea91d93f57fb54e816e
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=9b1621da295501241c8061487df75c2ff7e276ecbfce417953a26f7dc02aea8c
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16869 sha256=0c813752b2babbab1c750575da891306a7fd8e169932959a9911ae550cff5279
#   Stored in directory: /root/.cache/pip/wheels/f6/48/c4/942f7a1d556fddd2348cb9ac262f251873dfd8a39afec5678e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=35e316033ad418260add1a9791d44ad856eb389fb779b336fb7add5196b7b259
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/d9/7e068de779d863bc8f8fc9467d85e25cfe47fa5051fff1a1bb
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4629 sha256=4ca370b88ec2cd6d9b267aec90268a857ece2c502d049de5c65cf2c2927b54fe
#   Stored in directory: /root/.cache/pip/wheels/52/0e/51/514e690004ea9713bc3fdb678d5e2768fcc597d0c3b6a3abd2
# Successfully built pinyin gdown mpld3 jieba pycld2 word2number docopt sqlitedict langdetect pptree
# Installing collected packages: word2number, tokenizers, sqlitedict, sentencepiece, pycld2, py4j, pptree, pinyin, mpld3, lru-dict, keras, jieba, janome, flatbuffers, docopt, xxhash, terminaltables, tensorflow-hub, tensorflow-estimator, segtok, pyyaml, PySocks, num2words, networkx, multiprocess, more-itertools, MarkupSafe, lemminflect, langdetect, ftfy, fsspec, editdistance, deprecated, conllu, cloudpickle, click, anytree, wikipedia-api, tensorboardX, responses, pytorch-revgrad, OpenHowNet, language-tool-python, hyperopt, huggingface-hub, gensim, transformers, gdown, bpemb, tensorboard, datasets, bert-score, transformer-smaller-training-vocab, tensorflow, tensorflow-text, flair, textattack
#   Attempting uninstall: keras
#     Found existing installation: keras 2.10.0
#     Not uninstalling keras at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'keras'. No files were found to uninstall.
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 22.9.24
#     Not uninstalling flatbuffers at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'flatbuffers'. No files were found to uninstall.
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.10.0
#     Not uninstalling tensorflow-estimator at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'tensorflow-estimator'. No files were found to uninstall.
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.0
#     Not uninstalling markupsafe at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Not uninstalling click at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'click'. No files were found to uninstall.
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.10.1
#     Not uninstalling tensorboard at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'tensorboard'. No files were found to uninstall.
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.10.0
#     Not uninstalling tensorflow at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'tensorflow'. No files were found to uninstall.
# Successfully installed MarkupSafe-2.1.2 OpenHowNet-2.0 PySocks-1.7.1 anytree-2.8.0 bert-score-0.3.13 bpemb-0.3.4 click-8.0.4 cloudpickle-2.2.1 conllu-4.5.2 datasets-2.4.0 deprecated-1.2.13 docopt-0.6.2 editdistance-0.6.2 flair-0.12.2 flatbuffers-1.12 fsspec-2023.4.0 ftfy-6.1.1 gdown-4.4.0 gensim-4.3.1 huggingface-hub-0.13.4 hyperopt-0.2.7 janome-0.4.2 jieba-0.42.1 keras-2.9.0 langdetect-1.0.9 language-tool-python-2.7.1 lemminflect-0.2.3 lru-dict-1.1.8 more-itertools-9.1.0 mpld3-0.3 multiprocess-0.70.13 networkx-3.1 num2words-0.5.12 pinyin-0.4.0 pptree-3.1 py4j-0.10.9.7 pycld2-0.41 pytorch-revgrad-0.2.0 pyyaml-6.0 responses-0.18.0 segtok-1.5.11 sentencepiece-0.1.97 sqlitedict-2.1.0 tensorboard-2.9.1 tensorboardX-2.6 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-hub-0.13.0 tensorflow-text-2.9.0 terminaltables-3.1.10 textattack-0.3.8 tokenizers-0.13.3 transformer-smaller-training-vocab-0.2.3 transformers-4.27.4 wikipedia-api-0.5.8 word2number-1.1 xxhash-3.2.0
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip3 install textattack[tensorflow]
# Out:
# Requirement already satisfied: textattack[tensorflow] in /root/venv/lib/python3.9/site-packages (0.3.8)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (4.64.1)
# Requirement already satisfied: pycld2 in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (0.41)
# Requirement already satisfied: terminaltables in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (3.1.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (1.7.1)
# Requirement already satisfied: editdistance in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (0.6.2)
# Requirement already satisfied: numpy>=1.21.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (1.23.4)
# Requirement already satisfied: flair in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (0.11.3)
# Requirement already satisfied: lru-dict in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (1.1.8)
# Requirement already satisfied: num2words in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (0.5.12)
# Requirement already satisfied: pinyin==0.4.0 in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (0.4.0)
# Requirement already satisfied: filelock in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (3.8.0)
# Requirement already satisfied: bert-score>=0.3.5 in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (0.3.13)
# Requirement already satisfied: jieba in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (0.42.1)
# Requirement already satisfied: OpenHowNet in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (2.0)
# Requirement already satisfied: datasets==2.4.0 in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (2.4.0)
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (1.12.1)
# Requirement already satisfied: word2number in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (1.1)
# Requirement already satisfied: transformers>=4.21.0 in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (4.27.1)
# Requirement already satisfied: pandas>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (1.2.5)
# Requirement already satisfied: nltk in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (3.7)
# Requirement already satisfied: click<8.1.0 in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (8.0.4)
# Requirement already satisfied: language-tool-python in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (2.7.1)
# Requirement already satisfied: scipy>=1.4.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from textattack[tensorflow]) (1.9.3)
# Requirement already satisfied: lemminflect in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (0.2.3)
# Requirement already satisfied: more-itertools in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (9.1.0)
# Requirement already satisfied: tensorflow-hub in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (0.13.0)
# Requirement already satisfied: tensorflow-text>=2 in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (2.9.0)
# Requirement already satisfied: tensorflow==2.9.1 in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (2.9.1)
# Requirement already satisfied: tensorboardX in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (2.6)
# Requirement already satisfied: tensorflow-estimator==2.9.0 in /root/venv/lib/python3.9/site-packages (from textattack[tensorflow]) (2.9.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (9.0.0)
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (21.3)
# Requirement already satisfied: dill<0.3.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (0.3.5.1)
# Requirement already satisfied: requests>=2.19.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (2.28.1)
# Requirement already satisfied: xxhash in /root/venv/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (3.2.0)
# Requirement already satisfied: multiprocess in /root/venv/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (0.70.13)
# Requirement already satisfied: aiohttp in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (3.8.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /root/venv/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (2023.3.0)
# Requirement already satisfied: responses<0.19 in /root/venv/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (0.18.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /root/venv/lib/python3.9/site-packages (from datasets==2.4.0->textattack[tensorflow]) (0.13.2)
# Requirement already satisfied: astunparse>=1.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (4.4.0)
# Requirement already satisfied: six>=1.12.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (0.27.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (14.0.6)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /root/venv/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (2.9.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (3.19.6)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /root/venv/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (2.9.0)
# Requirement already satisfied: h5py>=2.9.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (0.4.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /root/venv/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.12)
# Requirement already satisfied: google-pasta>=0.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (0.2.0)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (58.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (1.50.0)
# Requirement already satisfied: termcolor>=1.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.9.1->textattack[tensorflow]) (2.0.1)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from bert-score>=0.3.5->textattack[tensorflow]) (3.6.0)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.0.1->textattack[tensorflow]) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=1.0.1->textattack[tensorflow]) (2.8.2)
# Requirement already satisfied: pyyaml>=5.1 in /root/venv/lib/python3.9/site-packages (from transformers>=4.21.0->textattack[tensorflow]) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from transformers>=4.21.0->textattack[tensorflow]) (2022.9.13)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /root/venv/lib/python3.9/site-packages (from transformers>=4.21.0->textattack[tensorflow]) (0.13.2)
# Requirement already satisfied: konoha<5.0.0,>=4.0.0 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (4.6.5)
# Requirement already satisfied: langdetect in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (1.0.9)
# Requirement already satisfied: conllu>=4.0 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (4.5.2)
# Requirement already satisfied: sqlitedict>=1.6.0 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (2.1.0)
# Requirement already satisfied: wikipedia-api in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (0.5.8)
# Requirement already satisfied: tabulate in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (0.9.0)
# Requirement already satisfied: segtok>=1.5.7 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (1.5.11)
# Requirement already satisfied: bpemb>=0.3.2 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (0.3.4)
# Requirement already satisfied: deprecated>=1.2.4 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (1.2.13)
# Requirement already satisfied: ftfy in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (6.1.1)
# Requirement already satisfied: pptree in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (3.1)
# Requirement already satisfied: mpld3==0.3 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (0.3)
# Requirement already satisfied: gensim>=3.4.0 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (4.3.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (1.1.2)
# Requirement already satisfied: lxml in /shared-libs/python3.9/py/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (4.9.1)
# Requirement already satisfied: sentencepiece==0.1.95 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (0.1.95)
# Requirement already satisfied: hyperopt>=0.2.7 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (0.2.7)
# Requirement already satisfied: gdown==4.4.0 in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (4.4.0)
# Requirement already satisfied: janome in /root/venv/lib/python3.9/site-packages (from flair->textattack[tensorflow]) (0.4.2)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from gdown==4.4.0->flair->textattack[tensorflow]) (4.11.1)
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk->textattack[tensorflow]) (1.2.0)
# Requirement already satisfied: docopt>=0.6.2 in /root/venv/lib/python3.9/site-packages (from num2words->textattack[tensorflow]) (0.6.2)
# Requirement already satisfied: anytree in /root/venv/lib/python3.9/site-packages (from OpenHowNet->textattack[tensorflow]) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow==2.9.1->textattack[tensorflow]) (0.38.4)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->datasets==2.4.0->textattack[tensorflow]) (4.0.2)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim>=3.4.0->flair->textattack[tensorflow]) (5.2.1)
# Requirement already satisfied: cloudpickle in /root/venv/lib/python3.9/site-packages (from hyperopt>=0.2.7->flair->textattack[tensorflow]) (2.2.1)
# Requirement already satisfied: networkx>=2.2 in /root/venv/lib/python3.9/site-packages (from hyperopt>=0.2.7->flair->textattack[tensorflow]) (3.0)
# Requirement already satisfied: py4j in /root/venv/lib/python3.9/site-packages (from hyperopt>=0.2.7->flair->textattack[tensorflow]) (0.10.9.7)
# Requirement already satisfied: future in /shared-libs/python3.9/py/lib/python3.9/site-packages (from hyperopt>=0.2.7->flair->textattack[tensorflow]) (0.18.2)
# Requirement already satisfied: overrides<4.0.0,>=3.0.0 in /root/venv/lib/python3.9/site-packages (from konoha<5.0.0,>=4.0.0->flair->textattack[tensorflow]) (3.1.0)
# Requirement already satisfied: importlib-metadata<4.0.0,>=3.7.0 in /root/venv/lib/python3.9/site-packages (from konoha<5.0.0,>=4.0.0->flair->textattack[tensorflow]) (3.10.1)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack[tensorflow]) (0.11.0)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.4.0->textattack[tensorflow]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.4.0->textattack[tensorflow]) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.19.0->datasets==2.4.0->textattack[tensorflow]) (1.26.12)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.21.3->flair->textattack[tensorflow]) (3.1.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (2.13.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /root/venv/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (3.3.4)
# Requirement already satisfied: wcwidth>=0.2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ftfy->flair->textattack[tensorflow]) (0.2.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata<4.0.0,>=3.7.0->konoha<5.0.0,>=4.0.0->flair->textattack[tensorflow]) (3.9.0)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-2.1.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4->gdown==4.4.0->flair->textattack[tensorflow]) (2.3.2.post1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[tensorflow]) (3.2.2)
# Installing collected packages: MarkupSafe
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.0
#     Not uninstalling markupsafe at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
# Successfully installed MarkupSafe-2.1.2
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /shared-libs/python3.9/py/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in /root/venv/lib/python3.9/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk) (2022.9.13)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
from textattack.transformations import WordSwapRandomCharacterDeletion
from textattack.transformations import WordSwapQWERTY
from textattack.transformations import CompositeTransformation

from textattack.constraints.pre_transformation import RepeatModification
from textattack.constraints.pre_transformation import StopwordModification

from textattack.augmentation import Augmenter

import textattack.augmentation.recipes
from textattack.augmentation.recipes import EasyDataAugmenter

import numpy as np # linear algebra
import pandas as pd

import nltk
from nltk.corpus import wordnet
import random

# %%
# Set up transformation using CompositeTransformation()
transformation = CompositeTransformation([WordSwapRandomCharacterDeletion(), WordSwapQWERTY()])
# Set up constraints
constraints = [RepeatModification(), StopwordModification()]
# Create augmenter with specified parameters
augmenter = Augmenter(transformation=transformation, constraints=constraints, pct_words_to_swap=0.5, transformations_per_example=10)
data = pd.read_csv("/work/input_tweets.csv")
df = pd.DataFrame(data) 
s = df.tweet
# Augment!
augmenter.augment(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [30], line 11
#       9 s = df.tweet
#      10 # Augment!
# ---> 11 augmenter.augment(s)
#
# File ~/venv/lib/python3.9/site-packages/textattack/augmentation/augmenter.py:113, in Augmenter.augment(self, text)
#     110 def augment(self, text):
#     111     """Returns all possible augmentations of ``text`` according to
#     112     ``self.transformation``."""
# --> 113     attacked_text = AttackedText(text)
#     114     original_text = attacked_text
#     115     all_transformed_texts = set()
#
# File ~/venv/lib/python3.9/site-packages/textattack/shared/attacked_text.py:55, in AttackedText.__init__(self, text_input, attack_attrs)
#      53     self._text_input = text_input
#      54 else:
# ---> 55     raise TypeError(
#      56         f"Invalid text_input type {type(text_input)} (required str or OrderedDict)"
#      57     )
#      58 # Process input lazily.
#      59 self._words = None
#
# TypeError: Invalid text_input type <class 'pandas.core.series.Series'> (required str or OrderedDict)

# %%
#EDA
from textattack.augmentation import EasyDataAugmenter
augmenter = EasyDataAugmenter(pct_words_to_swap=0.2, transformations_per_example=3)
s = 'What I cannot create, I do not understand.'
print(augmenter.augment(s))
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# ['What 1 cannot create, I do not understand.', 'What do cannot create, I I not understand.', 'What I cannot, I do not understand.']

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e803e9f0-f341-4e63-9e5c-ecfa91ec1687' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
